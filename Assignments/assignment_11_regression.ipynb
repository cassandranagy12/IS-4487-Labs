# %% [markdown]
# # IS 4487 Assignment 11: Predicting Airbnb Prices with Regression
#
# In this assignment, you will:
# - Load the Airbnb dataset you cleaned and transformed in Assignment 7
# - Build a linear regression model to predict listing price
# - Interpret which features most affect price
# - Try to improve your model using only the most impactful predictors
# - Practice explaining your findings to a business audience like a host, pricing strategist, or city partner
#
# ## Why This Matters
#
# Pricing is one of the most important levers for hosts and Airbnb’s business teams. Understanding what drives price — and being able to predict it accurately — helps improve search results, revenue management, and guest satisfaction.
#
# This assignment gives you hands-on practice turning a cleaned dataset into a predictive model. You’ll focus not just on code, but on what the results mean and how you’d communicate them to stakeholders.
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Assignments/assignment_11_regression.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Original Source: Dataset Description
#
# The dataset you'll be using is a **detailed Airbnb listing file**, available from [Inside Airbnb](https://insideairbnb.com/get-the-data/).
#
# Each row represents one property listing. The columns include:
#
# - **Host attributes** (e.g., host ID, host name, host response time)
# - **Listing details** (e.g., price, room type, minimum nights, availability)
# - **Location data** (e.g., neighborhood, latitude/longitude)
# - **Property characteristics** (e.g., number of bedrooms, amenities, accommodates)
# - **Calendar/booking variables** (e.g., last review date, number of reviews)
#
# The schema is consistent across cities, so you can expect similar columns regardless of the location you choose.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## 1. Load Your Transformed Airbnb Dataset
#
# **Business framing:**
# Before building any models, we must start with clean, prepared data. In Assignment 7, you exported a cleaned version of your Airbnb dataset. You’ll now import that file for analysis.
#
# ### Do the following:
# - Import your CSV file called `cleaned_airbnb_data_7.csv`.   (Note: If you had significant errors with assignment 7, you can use the file named "airbnb_listings.csv" in the DataSets folder on GitHub as a backup starting point.)
# - Use `pandas` to load and preview the dataset
#
# ### In Your Response:
# 1. What does the dataset include?
# 2. How many rows and columns are present?

# %%
# Add code here 🔧

# %%
df = pd.read_csv('cleaned_airbnb_data.csv')
display(df.head())
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  5456  https://www.airbnb.com/rooms/5456  20250613040113   2025-06-13
# 1  5769  https://www.airbnb.com/rooms/5769  20250613040113   2025-06-13
# 2  6413  https://www.airbnb.com/rooms/6413  20250613040113   2025-06-14
# 3  6448  https://www.airbnb.com/rooms/6448  20250613040113   2025-06-13
# 4  8502  https://www.airbnb.com/rooms/8502  20250613040113   2025-06-13
#
#             source                                               name  \
# 0      city scrape          Walk to 6th, Rainey St and Convention Ctr
# 1      city scrape                                     NW Austin Room
# 2  previous scrape                      Gem of a Studio near Downtown
# 3      city scrape  Secluded Studio @ Zilker - King Bed, Bright & ...
# 4      city scrape                            Woodland Studio Lodging
#
#                                          description  \
# 0  Great central  location for walking to Convent...
# 1                                                NaN
# 2  Great studio apartment, perfect a single perso...
# 3  Clean, private space with everything you need ...
# 4  Studio rental on lower level of home located i...
#
#                                neighborhood_overview  \
# 0  My neighborhood is ideally located if you want...
# 1  Quiet neighborhood with lots of trees and good...
# 2  Travis Heights is one of the oldest neighborho...
# 3  The neighborhood is fun and funky (but quiet)!...
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/14084884/b5a3...     8028  ...
# 1  https://a0.muscache.com/pictures/23822033/ac94...     8186  ...
# 2  https://a0.muscache.com/pictures/hosting/Hosti...    13879  ...
# 3  https://a0.muscache.com/pictures/airflow/Hosti...    14156  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...    25298  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.82                   4.73                4.79
# 1                        4.94                   4.77                4.92
# 2                        4.98                   4.87                4.93
# 3                        4.98                   4.97                4.88
# 4                        4.88                   4.69                4.63
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                            1.0
# 1     NaN                f                            1.0
# 2     NaN                f                            1.0
# 3     NaN                t                            1.0
# 4     NaN                f                            1.0
#
#   calculated_host_listings_count_entire_homes  \
# 0                                         1.0
# 1                                         0.0
# 2                                         1.0
# 3                                         1.0
# 4                                         1.0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                          0.0
# 1                                          1.0
# 2                                          0.0
# 3                                          0.0
# 4                                          0.0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                         0.0              3.59
# 1                                         0.0              1.65
# 2                                         0.0              0.65
# 3                                         0.0              2.02
# 4                                         0.0              0.29
#
# [5 rows x 79 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            2410 non-null   int64
#  1   listing_url                                   2410 non-null   object
#  2   scrape_id                                     2410 non-null   int64
#  3   last_scraped                                  2410 non-null   object
#  4   source                                        2410 non-null   object
#  5   name                                          2410 non-null   object
#  6   description                                   2345 non-null   object
#  7   neighborhood_overview                         1664 non-null   object
#  8   picture_url                                   2410 non-null   object
#  9   host_id                                       2410 non-null   int64
#  10  host_url                                      2410 non-null   object
#  11  host_name                                     2408 non-null   object
#  12  host_since                                    2408 non-null   object
#  13  host_location                                 2290 non-null   object
#  14  host_about                                    1649 non-null   object
#  15  host_response_time                            1007 non-null   object
#  16  host_response_rate                            1007 non-null   object
#  17  host_acceptance_rate                          1105 non-null   object
#  18  host_is_superhost                             2368 non-null   object
#  19  host_thumbnail_url                            2408 non-null   object
#  20  host_picture_url                              2408 non-null   object
#  21  host_neighbourhood                            2026 non-null   object
#  22  host_listings_count                           2408 non-null   float64
#  23  host_total_listings_count                     2408 non-null   float64
#  24  host_verifications                            2408 non-null   object
#  25  host_has_profile_pic                          2408 non-null   object
#  26  host_identity_verified                        2408 non-null   object
#  27  neighbourhood                                 1663 non-null   object
#  28  neighbourhood_cleansed                        2409 non-null   float64
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      2409 non-null   float64
#  31  longitude                                     2409 non-null   float64
#  32  property_type                                 2409 non-null   object
#  33  room_type                                     2409 non-null   object
#  34  accommodates                                  2409 non-null   float64
#  35  bathrooms                                     1043 non-null   float64
#  36  bathrooms_text                                2402 non-null   object
#  37  bedrooms                                      2109 non-null   float64
#  38  beds                                          1047 non-null   float64
#  39  amenities                                     2409 non-null   object
#  40  price                                         1047 non-null   object
#  41  minimum_nights                                2409 non-null   float64
#  42  maximum_nights                                2409 non-null   float64
#  43  minimum_minimum_nights                        2409 non-null   float64
#  44  maximum_minimum_nights                        2409 non-null   float64
#  45  minimum_maximum_nights                        2409 non-null   float64
#  46  maximum_maximum_nights                        2409 non-null   float64
#  47  minimum_nights_avg_ntm                        2409 non-null   float64
#  48  maximum_nights_avg_ntm                        2409 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              1758 non-null   object
#  51  availability_30                               2409 non-null   float64
#  52  availability_60                               2409 non-null   float64
#  53  availability_90                               2409 non-null   float64
#  54  availability_365                              2409 non-null   float64
#  55  calendar_last_scraped                         2409 non-null   object
#  56  number_of_reviews                             2409 non-null   float64
#  57  number_of_reviews_ltm                         2409 non-null   float64
#  58  number_of_reviews_l30d                        2409 non-null   float64
#  59  availability_eoy                              2409 non-null   float64
#  60  number_of_reviews_ly                          2409 non-null   float64
#  61  estimated_occupancy_l365d                     2409 non-null   float64
#  62  estimated_revenue_l365d                       1047 non-null   float64
#  63  first_review                                  1857 non-null   object
#  64  last_review                                   1857 non-null   object
#  65  review_scores_rating                          1857 non-null   float64
#  66  review_scores_accuracy                        1857 non-null   float64
#  67  review_scores_cleanliness                     1857 non-null   float64
#  68  review_scores_checkin                         1856 non-null   float64
#  69  review_scores_communication                   1857 non-null   float64
#  70  review_scores_location                        1855 non-null   float64
#  71  review_scores_value                           1855 non-null   float64
#  72  license                                       0 non-null      float64
#  73  instant_bookable                              2409 non-null   object
#  74  calculated_host_listings_count                2409 non-null   float64
#  75  calculated_host_listings_count_entire_homes   2409 non-null   float64
#  76  calculated_host_listings_count_private_rooms  2409 non-null   float64
#  77  calculated_host_listings_count_shared_rooms   2409 non-null   float64
#  78  reviews_per_month                             1857 non-null   float64
# dtypes: float64(43), int64(3), object(33)
# memory usage: 1.5+ MB

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1. The dataset includes all the data collected about specific airbnb rentals.
# 2. There is a max of 15,187 values and there are 79 columns present.

# %% [markdown]
# ## 2. Drop Columns Not Useful for Modeling
#
# **Business framing:**
# Some columns — like post IDs or text — may not help us predict price and could add noise or bias.
#
# ### Do the following:
# - Drop columns like `post_id`, `title`, `descr`, `details`, and `address` if they’re still in your dataset
#
# ### In Your Response:
# 1. What columns did you drop, and why?
# 2. What risks might occur if you included them in your model?

# %%
# Step 1: clean all the data FIRST
# Drop columns with all missing values
df.dropna(axis=1, how='all', inplace=True)

# Fill missing values in numeric columns with the mean
numeric_cols = df.select_dtypes(include=['number']).columns
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].mean())

display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2410 entries, 0 to 2409
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            2410 non-null   int64
#  1   listing_url                                   2410 non-null   object
#  2   scrape_id                                     2410 non-null   int64
#  3   last_scraped                                  2410 non-null   object
#  4   source                                        2410 non-null   object
#  5   name                                          2410 non-null   object
#  6   description                                   2345 non-null   object
#  7   neighborhood_overview                         1664 non-null   object
#  8   picture_url                                   2410 non-null   object
#  9   host_id                                       2410 non-null   int64
#  10  host_url                                      2410 non-null   object
#  11  host_name                                     2408 non-null   object
#  12  host_since                                    2408 non-null   object
#  13  host_location                                 2290 non-null   object
#  14  host_about                                    1649 non-null   object
#  15  host_response_time                            1007 non-null   object
#  16  host_response_rate                            1007 non-null   object
#  17  host_acceptance_rate                          1105 non-null   object
#  18  host_is_superhost                             2368 non-null   object
#  19  host_thumbnail_url                            2408 non-null   object
#  20  host_picture_url                              2408 non-null   object
#  21  host_neighbourhood                            2026 non-null   object
#  22  host_listings_count                           2410 non-null   float64
#  23  host_total_listings_count                     2410 non-null   float64
#  24  host_verifications                            2408 non-null   object
#  25  host_has_profile_pic                          2408 non-null   object
#  26  host_identity_verified                        2408 non-null   object
#  27  neighbourhood                                 1663 non-null   object
#  28  neighbourhood_cleansed                        2410 non-null   float64
#  29  latitude                                      2410 non-null   float64
#  30  longitude                                     2410 non-null   float64
#  31  property_type                                 2409 non-null   object
#  32  room_type                                     2409 non-null   object
#  33  accommodates                                  2410 non-null   float64
#  34  bathrooms                                     2410 non-null   float64
#  35  bathrooms_text                                2402 non-null   object
#  36  bedrooms                                      2410 non-null   float64
#  37  beds                                          2410 non-null   float64
#  38  amenities                                     2409 non-null   object
#  39  price                                         1047 non-null   object
#  40  minimum_nights                                2410 non-null   float64
#  41  maximum_nights                                2410 non-null   float64
#  42  minimum_minimum_nights                        2410 non-null   float64
#  43  maximum_minimum_nights                        2410 non-null   float64
#  44  minimum_maximum_nights                        2410 non-null   float64
#  45  maximum_maximum_nights                        2410 non-null   float64
#  46  minimum_nights_avg_ntm                        2410 non-null   float64
#  47  maximum_nights_avg_ntm                        2410 non-null   float64
#  48  has_availability                              1758 non-null   object
#  49  availability_30                               2410 non-null   float64
#  50  availability_60                               2410 non-null   float64
#  51  availability_90                               2410 non-null   float64
#  52  availability_365                              2410 non-null   float64
#  53  calendar_last_scraped                         2409 non-null   object
#  54  number_of_reviews                             2410 non-null   float64
#  55  number_of_reviews_ltm                         2410 non-null   float64
#  56  number_of_reviews_l30d                        2410 non-null   float64
#  57  availability_eoy                              2410 non-null   float64
#  58  number_of_reviews_ly                          2410 non-null   float64
#  59  estimated_occupancy_l365d                     2410 non-null   float64
#  60  estimated_revenue_l365d                       2410 non-null   float64
#  61  first_review                                  1857 non-null   object
#  62  last_review                                   1857 non-null   object
#  63  review_scores_rating                          2410 non-null   float64
#  64  review_scores_accuracy                        2410 non-null   float64
#  65  review_scores_cleanliness                     2410 non-null   float64
#  66  review_scores_checkin                         2410 non-null   float64
#  67  review_scores_communication                   2410 non-null   float64
#  68  review_scores_location                        2410 non-null   float64
#  69  review_scores_value                           2410 non-null   float64
#  70  instant_bookable                              2409 non-null   object
#  71  calculated_host_listings_count                2410 non-null   float64
#  72  calculated_host_listings_count_entire_homes   2410 non-null   float64
#  73  calculated_host_listings_count_private_rooms  2410 non-null   float64
#  74  calculated_host_listings_count_shared_rooms   2410 non-null   float64
#  75  reviews_per_month                             2410 non-null   float64
# dtypes: float64(40), int64(3), object(33)
# memory usage: 1.4+ MB
# None

# %%
# Step 2: Drop columns
columns_to_drop = ['maximum_nights_avg_ntm', 'minimum_nights_avg_ntm', 'maximum_maximum_nights','minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights','id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name', 'description', 'neighborhood_overview', 'picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'bathrooms_text', 'amenities', 'calendar_last_scraped', 'first_review', 'last_review']

# Drop columns that exist in the DataFrame
existing_columns_to_drop = [col for col in columns_to_drop if col in df.columns]
df.drop(columns=existing_columns_to_drop, inplace=True)

display(df.head())
# Out:
#    host_listings_count  host_total_listings_count  neighbourhood_cleansed  \
# 0                  1.0                        2.0                   78702
# 1                  1.0                        4.0                   78729
# 2                  1.0                        1.0                   78704
# 3                  1.0                        2.0                   78704
# 4                  1.0                        1.0                   78741
#
#    latitude  longitude         property_type        room_type  accommodates  \
# 0  30.26057  -97.73441     Entire guesthouse  Entire home/apt             3
# 1  30.45697  -97.78422  Private room in home     Private room             2
# 2  30.24885  -97.73587     Entire guesthouse  Entire home/apt             2
# 3  30.26034  -97.76487     Entire guesthouse  Entire home/apt             2
# 4  30.23466  -97.73682    Entire guest suite  Entire home/apt             2
#
#    bathrooms  bedrooms  ...  review_scores_checkin  \
# 0    1.00000  1.000000  ...                   4.90
# 1    1.00000  1.000000  ...                   4.91
# 2    1.73838  2.095101  ...                   4.99
# 3    1.00000  1.000000  ...                   4.99
# 4    1.00000  1.000000  ...                   4.85
#
#   review_scores_communication  review_scores_location  review_scores_value  \
# 0                        4.82                    4.73                 4.79
# 1                        4.94                    4.77                 4.92
# 2                        4.98                    4.87                 4.93
# 3                        4.98                    4.97                 4.88
# 4                        4.88                    4.69                 4.63
#
#   instant_bookable  calculated_host_listings_count  \
# 0                f                               1
# 1                f                               1
# 2                f                               1
# 3                t                               1
# 4                f                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            1
# 1                                            0
# 2                                            1
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             1
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               3.59
# 1                                            0               1.65
# 2                                            0               0.65
# 3                                            0               2.02
# 4                                            0               0.29
#
# [5 rows x 39 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15187 entries, 0 to 15186
# Data columns (total 39 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   host_listings_count                           15187 non-null  float64
#  1   host_total_listings_count                     15187 non-null  float64
#  2   neighbourhood_cleansed                        15187 non-null  int64
#  3   latitude                                      15187 non-null  float64
#  4   longitude                                     15187 non-null  float64
#  5   property_type                                 15187 non-null  object
#  6   room_type                                     15187 non-null  object
#  7   accommodates                                  15187 non-null  int64
#  8   bathrooms                                     15187 non-null  float64
#  9   bedrooms                                      15187 non-null  float64
#  10  beds                                          15187 non-null  float64
#  11  price                                         10708 non-null  object
#  12  minimum_nights                                15187 non-null  int64
#  13  maximum_nights                                15187 non-null  int64
#  14  has_availability                              13856 non-null  object
#  15  availability_30                               15187 non-null  int64
#  16  availability_60                               15187 non-null  int64
#  17  availability_90                               15187 non-null  int64
#  18  availability_365                              15187 non-null  int64
#  19  number_of_reviews                             15187 non-null  int64
#  20  number_of_reviews_ltm                         15187 non-null  int64
#  21  number_of_reviews_l30d                        15187 non-null  int64
#  22  availability_eoy                              15187 non-null  int64
#  23  number_of_reviews_ly                          15187 non-null  int64
#  24  estimated_occupancy_l365d                     15187 non-null  int64
#  25  estimated_revenue_l365d                       15187 non-null  float64
#  26  review_scores_rating                          15187 non-null  float64
#  27  review_scores_accuracy                        15187 non-null  float64
#  28  review_scores_cleanliness                     15187 non-null  float64
#  29  review_scores_checkin                         15187 non-null  float64
#  30  review_scores_communication                   15187 non-null  float64
#  31  review_scores_location                        15187 non-null  float64
#  32  review_scores_value                           15187 non-null  float64
#  33  instant_bookable                              15187 non-null  object
#  34  calculated_host_listings_count                15187 non-null  int64
#  35  calculated_host_listings_count_entire_homes   15187 non-null  int64
#  36  calculated_host_listings_count_private_rooms  15187 non-null  int64
#  37  calculated_host_listings_count_shared_rooms   15187 non-null  int64
#  38  reviews_per_month                             15187 non-null  float64
# dtypes: float64(16), int64(18), object(5)
# memory usage: 4.5+ MB

# %%
# Out:
# Scaled numerical columns:
# ['host_listings_count', 'host_total_listings_count', 'neighbourhood_cleansed', 'latitude', 'longitude', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'minimum_nights', 'maximum_nights', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'availability_eoy', 'number_of_reviews_ly', 'estimated_occupancy_l365d', 'estimated_revenue_l365d', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']
#    host_listings_count  host_total_listings_count  neighbourhood_cleansed  \
# 0            -0.206809                  -0.211216               -1.075487
# 1            -0.206809                  -0.208888                0.222251
# 2            -0.206809                  -0.212381               -0.979358
# 3            -0.206809                  -0.211216               -0.979358
# 4            -0.206809                  -0.212381                0.799023
#
#    latitude  longitude  accommodates  bathrooms  bedrooms      beds    price  \
# 0 -0.308152   0.247408     -0.586211  -0.839966 -0.784119 -0.388463  $101.00
# 1  2.751947  -0.525182     -0.878067  -0.839966 -0.784119 -0.788097   $45.00
# 2 -0.490760   0.224762     -0.878067   0.000000  0.000000  0.000000      NaN
# 3 -0.311735  -0.225049     -0.878067  -0.839966 -0.784119 -0.388463  $155.00
# 4 -0.711854   0.210027     -0.878067  -0.839966 -0.784119 -0.788097   $43.00
#
#    ...  property_type_Tower  property_type_Treehouse  property_type_Yurt  \
# 0  ...                False                    False               False
# 1  ...                False                    False               False
# 2  ...                False                    False               False
# 3  ...                False                    False               False
# 4  ...                False                    False               False
#
#    room_type_Entire home/apt  room_type_Hotel room  room_type_Private room  \
# 0                       True                 False                   False
# 1                      False                 False                    True
# 2                       True                 False                   False
# 3                       True                 False                   False
# 4                       True                 False                   False
#
#    room_type_Shared room  has_availability_t  instant_bookable_f  \
# 0                  False                True                True
# 1                  False                True                True
# 2                  False                True                True
# 3                  False                True               False
# 4                  False                True                True
#
#    instant_bookable_t
# 0               False
# 1               False
# 2               False
# 3                True
# 4               False
#
# [5 rows x 110 columns]

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1. I droped a lot of variables that either had photo links, long discriptions, id, names, etc.
#
# 2. Risks that could occur are the data would not be repersentitive of the actual data, there was a lot of noise that needed to be cleaned up.

# %% [markdown]
# ## 3. Explore Relationships Between Numeric Features
#
# **Business framing:**
# Understanding how features relate to each other — and to the target — helps guide feature selection and modeling.
#
# ### Do the following:
# - Generate a correlation matrix
# - Identify which variables are strongly related to `price`
#
# ### In Your Response:
# 1. Which variables had the strongest positive or negative correlation with price?
# 2. Which variables might be useful predictors?

# %%
# Add code here 🔧

# %%
# Convert 'price' to numeric, handling potential errors and removing '$'
df['price'] = df['price'].astype(str).str.replace('[$,]', '', regex=True)
df['price'] = pd.to_numeric(df['price'], errors='coerce')

# Drop rows where price could not be converted to numeric
df.dropna(subset=['price'], inplace=True)

# Calculate the correlation matrix with 'price'
correlation_matrix = df.corr()['price'].sort_values(ascending=False)

# Drop NaN values from the correlation matrix
correlation_matrix.dropna(inplace=True)

display(correlation_matrix)
# Out:
# price                          1.000000
# room_type_Hotel room           0.690135
# host_total_listings_count      0.394259
# estimated_revenue_l365d        0.366934
# property_type_Room in hotel    0.331316
#                                  ...
# number_of_reviews_ltm         -0.054318
# estimated_occupancy_l365d     -0.075099
# instant_bookable_f            -0.079704
# longitude                     -0.081083
# room_type_Entire home/apt     -0.102876
# Name: price, Length: 101, dtype: float64

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1.
#
# 2.

# %% [markdown]
# ## 4. Define Features and Target Variable
#
# **Business framing:**
# To build a regression model, you need to define what you’re predicting (target) and what you’re using to make that prediction (features).
#
# ### Do the following:
# - Set `price` as your target variable
# - Remove `price` from your predictors
#
# ### In Your Response:
# 1. What features are you using?
# 2. Why is this a regression problem and not a classification problem?

# %%
# Add code here 🔧

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1.
#
# 2.

# %% [markdown]
# ## 5. Split Data into Training and Testing Sets
#
# ### Business framing:
# Splitting your data lets you train a model and test how well it performs on new, unseen data.
#
# ### Do the following:
# - Use `train_test_split()` to split into 80% training, 20% testing

# %%
# Add code here 🔧

# %% [markdown]
# ## 6. Fit a Linear Regression Model
#
# ### Business framing:
# Linear regression helps you quantify the impact of each feature on price and make predictions for new listings.
#
# ### Do the following:
# - Fit a linear regression model to your training data
# - Use it to predict prices for the test set

# %%
# Add code here 🔧

# %% [markdown]
# ## 7. Evaluate Model Performance
#
# ### Business framing:
# A good model should make accurate predictions. We’ll use Mean Squared Error (MSE) and R² to evaluate how close our predictions were to the actual prices.
#
# ### Do the following:
# - Print MSE and R² score for your model
#
# ### In Your Response:
# 1. What is your R² score? How well does your model explain price variation?
# 2. Is your MSE large or small? What could you do to improve it?

# %%
# Add code here 🔧

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1.
#
# 2.

# %% [markdown]
# ## 8. Interpret Model Coefficients
#
# ### Business framing:
# The regression coefficients tell you how each feature impacts price. This can help Airbnb guide hosts and partners.
#
# ### Do the following:
# - Create a table showing feature names and regression coefficients
# - Sort the table so that the most impactful features are at the top
#
# ### In Your Response:
# 1. Which features increased price the most?
# 2. Were any surprisingly negative?
# 3. What business insight could you draw from this?

# %%
# Add code here 🔧

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1.
#
# 2.
#
# 3.

# %% [markdown]
# ## 9. Try to Improve the Linear Regression Model
#
# ### Business framing:
# The first version of your model included all available features — but not all features are equally useful. Removing weak or noisy predictors can often improve performance and interpretation.
#
# ### Do the following:
# 1. Choose your top 3–5 features with the strongest absolute coefficients
# 2. Rebuild the regression model using just those features
# 3. Compare MSE and R² between the baseline and refined model
#
# ### In Your Response:
# 1. What features did you keep in the refined model, and why?
# 2. Did model performance improve? Why or why not?
# 3. Which model would you recommend to stakeholders?
# 4. How does this relate to your customized learning outcome you created in canvas?

# %%
# Add code here 🔧

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1.
#
# 2.
#
# 3.
#
# 4.

# %% [markdown]
# ## 10. Reflect and Recommend
#
# ### Business framing:
# Ultimately, the value of your model comes from how well it can guide business decisions. Use your results to make real-world recommendations.
#
# ### In Your Response:
# 1. What business question did your model help answer?
# 2. What would you recommend to Airbnb or its hosts?
# 3. What could you do next to improve this model or make it more useful?
# 4. How does this relate to your customized learning outcome you created in canvas?

# %% [markdown]
# ### ✍️ Your Response: 🔧
# 1.
#
# 2.
#
# 3.
#
# 4.

# %% [markdown]
# ## Submission Instructions
# ✅ Checklist:
# - All code cells run without error
# - All markdown responses are complete
# - Submit on Canvas as instructed

# %%
# !jupyter nbconvert --to html "assignment_11_LastnameFirstname.ipynb"
